# %% [markdown]
# <a href="https://colab.research.google.com/github/Doclikam/Python-pydata/blob/main/cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cars=pd.read_csv('/car_prices (1).csv')

# %%
cars.info()
cars.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199648 entries, 0 to 199647
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          199648 non-null  int64
#  1   make          197373 non-null  object
#  2   model         197333 non-null  object
#  3   trim          197044 non-null  object
#  4   body          194500 non-null  object
#  5   transmission  176047 non-null  object
#  6   vin           199648 non-null  object
#  7   state         199648 non-null  object
#  8   condition     187855 non-null  float64
#  9   odometer      199570 non-null  float64
#  10  color         199339 non-null  object
#  11  interior      199339 non-null  object
#  12  seller        199648 non-null  object
#  13  mmr           199648 non-null  int64
#  14  sellingprice  199648 non-null  int64
#  15  saledate      199648 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 24.4+ MB
# ...

# %%
cars.head(20)
# Out:
#     year       make                model                       trim  \
# 0   2015        Kia              Sorento                         LX
# 1   2015        Kia              Sorento                         LX
# 2   2014        BMW             3 Series                 328i SULEV
# 3   2015      Volvo                  S60                         T5
# 4   2014        BMW  6 Series Gran Coupe                       650i
# 5   2015     Nissan               Altima                      2.5 S
# 6   2014        BMW                   M5                       Base
# 7   2014  Chevrolet                Cruze                        1LT
# 8   2014       Audi                   A4  2.0T Premium Plus quattro
# 9   2014  Chevrolet               Camaro                         LT
# 10  2014       Audi                   A6      3.0T Prestige quattro
# 11  2015        Kia               Optima                         LX
# 12  2015       Ford               Fusion                         SE
# ...

# %%
cars['make'].value_counts()
cars['body'].value_counts()
# Out:
# body
# Sedan                      86671
# SUV                        51348
# Minivan                     9399
# Hatchback                   9095
# Coupe                       6357
# Wagon                       6058
# Crew Cab                    5368
# Convertible                 3713
# SuperCrew                   2872
# G Sedan                     2578
# SuperCab                    1917
# Van                         1716
# Extended Cab                1667
# Regular Cab                 1594
# Quad Cab                    1429
# E-Series Van                 589
# G Coupe                      538
# Double Cab                   463
# King Cab                     200
# CrewMax Cab                  194
# Genesis Coupe                108
# G Convertible                101
# Access Cab                    93
# Club Cab                      71
# Koup                          63
# CTS Coupe                     54
# sedan                         44
# Elantra Coupe                 29
# ...

# %%
cars.groupby('year')['model'].value_counts().sort_values(ascending=False)
# Out:
# year  model
# 2012  Altima        3223
# 2013  Altima        1527
# 2012  Accord        1336
# 2013  Escape        1310
# 2012  Fusion        1260
#                     ...
# 2005  Safari           1
#       MX-5 Miata       1
#       M3               1
#       GS 300           1
# 2015  6 Series         1
# Name: count, Length: 5064, dtype: int64
