# %% [markdown]
# <a href="https://colab.research.google.com/github/Doclikam/Python-pydata/blob/main/Getting_Financial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
pip install yfinance

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime as dt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
date=pd.date_range(start='01/01/2015', end='04-08-2024')
date
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2024-03-30', '2024-03-31', '2024-04-01', '2024-04-02',
#                '2024-04-03', '2024-04-04', '2024-04-05', '2024-04-06',
#                '2024-04-07', '2024-04-08'],
#               dtype='datetime64[ns]', length=3386, freq='D')

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
amazon_stock='AMZN'
start_date='2015-01-01'
end_date='2024-01-01'

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
df=yf.download(amazon_stock, start=start_date, end=end_date)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-02   15.629000   15.737500   15.348000   15.426000   15.426000
# 2015-01-05   15.350500   15.419000   15.042500   15.109500   15.109500
# 2015-01-06   15.112000   15.150000   14.619000   14.764500   14.764500
# 2015-01-07   14.875000   15.064000   14.766500   14.921000   14.921000
# 2015-01-08   15.016000   15.157000   14.805500   15.023000   15.023000
# ...                ...         ...         ...         ...         ...
# 2023-12-22  153.770004  154.350006  152.710007  153.419998  153.419998
# 2023-12-26  153.559998  153.979996  153.029999  153.410004  153.410004
# 2023-12-27  153.559998  154.779999  153.119995  153.339996  153.339996
# 2023-12-28  153.720001  154.080002  152.949997  153.380005  153.380005
# 2023-12-29  153.100006  153.889999  151.029999  151.940002  151.940002
#
#               Volume
# Date
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-01-03  85.459999  86.959999  84.209999  85.820000  85.820000  76706000
# 2023-01-04  86.550003  86.980003  83.360001  85.139999  85.139999  68885100
# 2023-01-05  85.330002  85.419998  83.070000  83.120003  83.120003  67930800
# 2023-01-06  83.029999  86.400002  81.430000  86.080002  86.080002  83303400
# 2023-01-09  87.459999  89.480003  87.080002  87.360001  87.360001  65266100

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol=pd.DataFrame(df['Volume'])
vol
# Out:
#               Volume
# Date
# 2015-01-02  55664000
# 2015-01-05  55484000
# 2015-01-06  70380000
# 2015-01-07  52806000
# 2015-01-08  61768000
# ...              ...
# 2023-12-22  29480100
# 2023-12-26  25067200
# 2023-12-27  31434700
# 2023-12-28  27057000
# 2023-12-29  39789000
#
# [2264 rows x 1 columns]

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol['Volume'].resample('W').agg(['mean','median'])
# Out:
#                    mean      median
# Date
# 2015-01-04   55664000.0  55664000.0
# 2015-01-11   58457200.0  55484000.0
# 2015-01-18   83975600.0  82728000.0
# 2015-01-25  114996000.0  98590000.0
# 2015-02-01  166666000.0  63394000.0
# ...                 ...         ...
# 2023-12-03   48564720.0  42711700.0
# 2023-12-10   45801280.0  46822400.0
# 2023-12-17   63411540.0  52766200.0
# 2023-12-24   44358400.0  43171300.0
# 2023-12-31   30836975.0  29245850.0
#
# [470 rows x 2 columns]

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
vol.reset_index(inplace=True)
vol['Date']
# Out:
# 0      2015-01-02
# 1      2015-01-05
# 2      2015-01-06
# 3      2015-01-07
# 4      2015-01-08
#           ...
# 2259   2023-12-22
# 2260   2023-12-26
# 2261   2023-12-27
# 2262   2023-12-28
# 2263   2023-12-29
# Name: Date, Length: 2264, dtype: datetime64[ns]

# %%
vol['year']=vol['Date'].dt.year

# %% [markdown]
# ### BONUS: Create your own question and answer it.
